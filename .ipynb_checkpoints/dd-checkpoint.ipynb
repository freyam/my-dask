# %% [markdown]
# # Dask DataFrames

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import dask
import dask.dataframe as dd

# %%
import dask.dataframe as dd

df = dd.demo.make_timeseries(start='2000', end='2015', dtypes={'A': float, 'B': int},
                             freq='5s', partition_freq='3M', seed=1234)
df = df.A.cumsum().resample('1w').mean()

df.dask
# Out:
# HighLevelGraph with 7 layers.
# <dask.highlevelgraph.HighLevelGraph object at 0x7fc7fa0835b0>
#  0. make-timeseries-1ba89bf52cd6a20f931d66af31e675da
#  1. getitem-7b8e37c0dbf2075919f66904043369be
#  2. series-cumsum-map-2a8d834238a9585c1370cae7d28e11ae
#  3. series-cumsum-take-last-a2e8fc58167c0e2417e6d7fe1a7b98be
#  4. series-cumsum-312032aacfb5bcf57c6a22ec0e19399e
#  5. repartition-merge-bd53299b6105790270bfd1b40206bc7a
#  6. resample-b3a9af2c7dc97c963da89acdf48253cc

# %%
import dask
import dask.dataframe as dd

df = dask.datasets.timeseries()
df2 = df[df.y > 0]
df3 = df2.groupby('name').x.std()

df3.dask
# Out:
# HighLevelGraph with 7 layers.
# <dask.highlevelgraph.HighLevelGraph object at 0x7fc7fa083700>
#  0. make-timeseries-0a9074337242d1aa8202646c1912ccf7
#  1. getitem-9809151bcb234507e87598f969017800
#  2. gt-c6f16194fb97257a0de0952b16f2037e
#  3. getitem-71f21c37c3ec5801e84ec4c15a7bc61b
#  4. series-groupby-var-agg-52e5d68b43a3849b51b559480f80fdc9
#  5. getitem-39f81bd1cbad4d833432ace798ee16aa
#  6. sqrt-52f6ccaeab4600adda6113a4c19643a4
