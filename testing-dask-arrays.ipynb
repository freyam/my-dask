# %% [markdown]
# # Dask Array

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import dask
import dask.array as da
import pytest
from dask.highlevelgraph import to_graphviz

# %%
import dask.array as da

x = da.ones((10, 10), chunks=(5, 5))
x = x + 100
x = x * 100

x.dask.visualize(filename="whatextension.png", format='pdf') # whatextension.png.pdf
x.dask.visualize(filename="whatextension", format=None) # whatextension.png

# %%
import dask.array as da

XL = da.ones((67552, 365941), chunks=(652, 5792))
XL2 = XL.T.astype("f4")
XC = da.ones((365941, 26), chunks=(365941, 26))
LS = da.linalg.lstsq(XC, XL2)[0]
XC_LS = XC @ LS
XLP = XL2 - XC_LS

XLP.dask.visualize(color="layer_type")

# %%
a = da.ones((1000, 1000), chunks=(100, 100))
b = a + a.T
c = b.sum(axis=1)


c.dask.visualize(color="layer_type", filename="7974-Z.png")
