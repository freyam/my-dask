# %%
import dask.array as da

x = da.ones((10, 10), chunks=(5, 5))
x = x + 100
x = x * 100

x.dask.visualize()
# Out:
# HighLevelGraph with 2 layers.
# ...
#  0. ones_like-dae9b727a2786ca6938471f082f8e3c1
#  1. transpose-94e5f53a2ae88f1546d5fd82ffc8e7fd
