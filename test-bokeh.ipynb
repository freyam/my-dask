# %%
from dask.distributed import Client
client = Client()
client
# Out:
# <Client: 'tcp://127.0.0.1:37095' processes=4 threads=8, memory=15.52 GiB>

# %%
import dask.array as da

a = da.ones((20), chunks=(5))
b = da.dot(a, a)
c = b + 10

c.dask.visualize()
